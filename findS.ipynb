# %%
import pandas as pd

# Read data from the CSV file
df = pd.read_csv('findSdata2.csv')

# Extract the examples from the DataFrame
examples = df.values.tolist()
# print(examples)
# Define a function for the Find-S algorithm
def findS(examples):
    # Initialize the hypothesis to the most specific hypothesis
    hypothesis = ['0'] * (len(examples[0]) - 1)
   
   
    c = 0
    for example in examples:
        # If the example is a positive example
        if example[-1] == 'Yes':
            for i in range(len(hypothesis)):
                # If the hypothesis is more general than the example, update it
                if c == 0 :
                    hypothesis[i] = example[i]
                else:
                    if hypothesis[i] != example[i]:
                        hypothesis[i] = '?'
                    else:
                        hypothesis[i] = example[i]
            c += 1
        print(hypothesis)
                   
    return hypothesis

# Find the hypothesis using the Find-S algorithm
hypothesis = findS(examples)

# Print the final hypothesis
print("Final hypothesis:")
print(hypothesis)
# Out:
# ['John', 'A', 'Math', '>90']
# ['John', 'A', 'Math', '>90']
# ['John', 'A', 'Math', '>90']
# ['John', 'A', 'Math', '>90']
# ['John', 'A', 'Math', '>90']
# ['John', 'A', 'Math', '>90']
# ['John', 'A', 'Math', '>90']
# ['John', 'A', 'Math', '>90']
# ['John', 'A', 'Math', '>90']
# ['John', 'A', 'Math', '>90']
# ['John', 'A', 'Math', '>90']
# ['John', 'A', 'Math', '>90']
# Final hypothesis:
# ['John', 'A', 'Math', '>90']

# %%
import pandas as pd

# Read data from the CSV file
df = pd.read_csv('findS.csv')

# Extract the examples from the DataFrame
examples = df.values.tolist()
# print(examples)
# Define a function for the Find-S algorithm
def findS(examples):
    # Initialize the hypothesis to the most specific hypothesis
    hypothesis = ['0'] * (len(examples[0]) - 1)
   
   
    c = 0
    for example in examples:
        # If the example is a positive example
        if example[-1] == 'Yes':
            for i in range(len(hypothesis)):
                # If the hypothesis is more general than the example, update it
                if c == 0 :
                    hypothesis[i] = example[i]
                else:
                    if hypothesis[i] != example[i]:
                        hypothesis[i] = '?'
                    else:
                        hypothesis[i] = example[i]
            c += 1
        print(hypothesis)
                   
    return hypothesis

# Find the hypothesis using the Find-S algorithm
hypothesis = findS(examples)

# Print the final hypothesis
print("Final hypothesis:")
print(hypothesis)
# Out:
# ['Jp', 'Honda', 'Blue', 1980, 'Eco']
# ['Jp', 'Honda', 'Blue', 1980, 'Eco']
# ['Jp', '?', 'Blue', '?', 'Eco']
# ['Jp', '?', 'Blue', '?', 'Eco']
# ['Jp', '?', '?', '?', 'Eco']
# ['Jp', '?', '?', '?', 'Eco']
# ['Jp', '?', '?', '?', 'Eco']
# Final hypothesis:
# ['Jp', '?', '?', '?', 'Eco']

# %%
import pandas as pd

# Read data from the CSV file
df = pd.read_csv('findS.csv')

# Extract the examples from the DataFrame
examples = df.values.tolist()

# Define a function for the Find-S algorithm
def findS(examples):
    # Initialize the hypothesis to the most specific hypothesis
    hypothesis = ['0'] * (len(examples[0]) - 1)

    c = 0
    correct_predictions = 0
    total_predictions = 0

    for example in examples:
        total_predictions += 1
        # If the example is a positive example
        if example[-1] == 'Yes':
            for i in range(len(hypothesis)):
                if c == 0:
                    hypothesis[i] = example[i]
                else:
                    if hypothesis[i] != example[i]:
                        hypothesis[i] = '?'
                    else:
                        hypothesis[i] = example[i]
            c += 1
            # Check if the predicted hypothesis matches the true label
            if all(h == '?' or h == e for h, e in zip(hypothesis, example[:-1])):
                correct_predictions += 1

    accuracy = correct_predictions / total_predictions
    print("Accuracy:", accuracy)

    return hypothesis

# Find the hypothesis using the Find-S algorithm and calculate accuracy
hypothesis = findS(examples)

# Print the final hypothesis
print("Final hypothesis:")
print(hypothesis)
# Out:
# Accuracy: 0.5714285714285714
# Final hypothesis:
# ['Jp', '?', '?', '?', 'Eco']

# %%
import pandas as pd

# Read data from the CSV file
df = pd.read_csv('findS.csv')

# Extract the examples from the DataFrame
examples = df.values.tolist()

print(examples)

# Define a function for the Find-S algorithm
def findS(examples):
    # Initialize the hypothesis to the most specific hypothesis
    hypothesis = ['0'] * (len(examples[0]) - 1)

    c = 0
    correct_predictions = 0
    total_predictions = 0

    for example in examples:
        total_predictions += 1
        # print('value=',total_predictions)
        # If the example is a positive example
        if example[-1] == 'Yes':
            for i in range(len(hypothesis)):
                if c == 0:
                    hypothesis[i] = example[i]
                else:
                    if hypothesis[i] != example[i]:
                        hypothesis[i] = '?'
                    else:
                        hypothesis[i] = example[i]
            c += 1
            print(hypothesis)
            # Check if the predicted hypothesis matches the true label
            if all(h == '?' or h == e for h, e in zip(hypothesis, example[:-1])):
                correct_predictions += 1
                # print(correct_predictions)
    
    accuracy = correct_predictions / total_predictions
    print("Accuracy:", accuracy)
    return hypothesis

# Find the hypothesis using the Find-S algorithm and calculate accuracy
hypothesis = findS(examples)

# Print the final hypothesis
print("Final hypothesis:")
print(hypothesis)
# Out:
# [['Jp', 'Honda', 'Blue', 1980, 'Eco', 'Yes'], ['Jp', 'Toyota', 'Green', 1970, 'Spo', 'No'], ['Jp', 'Toyata', 'Blue', 1990, 'Eco', 'Yes'], ['Usa', 'Audi', 'Red', 1980, 'Eco', 'No'], ['Jp', 'Honda', 'White', 1980, 'Eco', 'Yes'], ['Jp', 'Toyata', 'Green', 1980, 'Eco', 'Yes'], ['Jp', 'Honda', 'Red', 1980, 'Eco', 'No']]
# ['Jp', 'Honda', 'Blue', 1980, 'Eco']
# ['Jp', '?', 'Blue', '?', 'Eco']
# ['Jp', '?', '?', '?', 'Eco']
# ['Jp', '?', '?', '?', 'Eco']
# Accuracy: 0.5714285714285714
# Final hypothesis:
# ['Jp', '?', '?', '?', 'Eco']

# %%
import pandas as pd

# Read data from the CSV file
df = pd.read_csv('t2.csv')

# Extract the examples from the DataFrame
examples = df.values.tolist()

# Define a function for the Find-S algorithm
def findS(examples):
    # Initialize the hypothesis to the most specific hypothesis
    hypothesis = ['0'] * (len(examples[0]) - 1)

    c = 0
    correct_predictions = 0
    total_predictions = 0

    for example in examples:
        print(example)
        total_predictions += 1
        # If the example is a positive example
        if example[-1] == 'Yes':
            for i in range(len(hypothesis)):
                if c == 0:
                    hypothesis[i] = example[i]
                else:
                    if hypothesis[i] != example[i]:
                        hypothesis[i] = '?'
                    else:
                        hypothesis[i] = example[i]
            c += 1
            print(hypothesis)
            # Check if the predicted hypothesis matches the true label
            if all(h == '?' or h == e for h, e in zip(hypothesis, example[:-1])):
                correct_predictions += 1
                print(correct_predictions)
    
    accuracy = correct_predictions / total_predictions
    print("Accuracy:", accuracy)

    return hypothesis

# Find the hypothesis using the Find-S algorithm and calculate accuracy
hypothesis = findS(examples)

# Print the final hypothesis
print("Final hypothesis:")
print(hypothesis)
# Out:
# [1, 1, 'Yes']
# [1, 1]
# 1
# Accuracy: 1.0
# Final hypothesis:
# [1, 1]
